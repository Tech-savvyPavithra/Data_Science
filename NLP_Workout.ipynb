# %% [markdown]
# <a href="https://colab.research.google.com/github/Tech-savvyPavithra/Data_Science/blob/main/NLP_Workout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read pdf file with python
# !pip install PyPDF2
# Importing required modules
import PyPDF2

# %%
# Creating a pdf file object
data=open('/content/drive/MyDrive/Courses Codes and Datasets/Great Learning/The_Marvel.pdf','rb')
data
# Out:
# <_io.BufferedReader name='/content/drive/MyDrive/Courses Codes and Datasets/Great Learning/The_Marvel.pdf'>

# %%
# Creating a pdf reader object
reader=PyPDF2.PdfReader(data)
# Printing number of pages in pdf file
print(len(reader.pages))
# Out:
# 2

# %%
# Creating a page object
page=reader.pages[0]
page
print(page)
# Out:
# {'/Type': '/Page', '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'], '/ExtGState': {'/G3': IndirectObject(3, 0, 134660122470592)}, '/Font': {'/F4': IndirectObject(4, 0, 134660122470592)}}, '/MediaBox': [0, 0, 612, 792], '/Contents': IndirectObject(5, 0, 134660122470592), '/StructParents': 0, '/Parent': IndirectObject(8, 0, 134660122470592)}

# %%
# Extracting text from page
print(page.extract_text())
# Out:
# T
# h
# e
# M
# a
# r
# v
# e
# l
# C
# i
# n
# e
# m
# a
# t
# i
# c
# U
# n
# i
# v
# e
# r
# s
# e
# (
# M
# C
# U
# )
# i
# s
# a
# n
# A
# m
# e
# r
# i
# c
# a
# n
# m
# e
# d
# i
# a
# f
# r
# a
# n
# c
# h
# i
# s
# e
# a
# n
# d
# s
# h
# a
# r
# e
# d
# u
# n
# i
# v
# e
# r
# s
# e
# c
# e
# n
# t
# e
# r
# e
# d
# o
# n
# a
# s
# e
# r
# i
# e
# s
# o
# f
# s
# u
# p
# e
# r
# h
# e
# r
# o
# f
# i
# l
# m
# s
# p
# r
# o
# d
# u
# c
# e
# d
# b
# y
# M
# a
# r
# v
# e
# l
# S
# t
# u
# d
# i
# o
# s
# .
# T
# h
# e
# f
# i
# l
# m
# s
# a
# r
# e
# b
# a
# s
# e
# d
# o
# n
# c
# h
# a
# r
# a
# c
# t
# e
# r
# s
# t
# h
# a
# t
# a
# p
# p
# e
# a
# r
# i
# n
# A
# m
# e
# r
# i
# c
# a
# n
# c
# o
# m
# i
# c
# b
# o
# o
# k
# s
# p
# u
# b
# l
# i
# s
# h
# e
# d
# b
# y
# M
# a
# r
# v
# e
# l
# C
# o
# m
# i
# c
# s
# .
# T
# h
# e
# f
# r
# a
# n
# c
# h
# i
# s
# e
# a
# l
# s
# o
# i
# n
# c
# l
# u
# d
# e
# s
# t
# e
# l
# e
# v
# i
# s
# i
# o
# n
# s
# e
# r
# ...

# %%
# Closing the pdf file object
data.close()

# %%
# Working with text file in Python
text_data=open("/content/drive/MyDrive/Colab Notebooks/My Workouts/Chatbot.txt","r")
print(text_data.read())
# Out:
# ﻿Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.[2]
#
#
# The existence of Comet NEOWISE (here depicted as a series of red dots) was discovered by analyzing astronomical survey data acquired by a space telescope, the Wide-field Infrared Survey Explorer.
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
# Working with CSV file
import numpy as np
import pandas as pd
data=pd.read_csv("/content/drive/MyDrive/Courses Codes and Datasets/Great Learning/Train.csv")
data
# Out:
#                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
# [40000 rows x 2 columns]

# %%
data.head()
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
data.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
data.shape
# Out:
# (40000, 2)

# %%
data.describe()
# Out:
#               label
# count  40000.000000
# mean       0.499525
# std        0.500006
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
data.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# text     False
# label    False
# dtype: bool

# %%
data_part=data.dropna()
data_part
# Out:
#                                                     text  label
# 0      I grew up (b. 1965) watching and loving the Th...      0
# 1      When I put this movie in my DVD player, and sa...      0
# 2      Why do people who do not know what a particula...      0
# 3      Even though I have great interest in Biblical ...      0
# 4      Im a die hard Dads Army fan and nothing will e...      1
# ...                                                  ...    ...
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1
#
# [40000 rows x 2 columns]

# %%
data_part.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data_part.shape
# Out:
# (40000, 2)

# %%
# Line tokenization
import nltk
nltk.download('punkt')
data="Welcome to Great Learning. I am happy"
tokens=nltk.sent_tokenize(data)
print(tokens)
# Out:
# ['Welcome to Great Learning.', 'I am happy']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Word tokenization
tokens=nltk.word_tokenize(data)
print(tokens)
# Out:
# ['Welcome', 'to', 'Great', 'Learning', '.', 'I', 'am', 'happy']

# %%
len(tokens)
# Out:
# 8

# %%
type(tokens)
# Out:
# list

# %%
# Stemming
# import these modules
from nltk.stem import PorterStemmer
ps=PorterStemmer()
# Choose some words to be stemmed
words=["Like","Liking","Likes"]
for i in words:
    print(i,":",ps.stem(i))
# Out:
# Like : like
# Liking : like
# Likes : like

# %%
# Lemmatization
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# import these modules
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
print("socks:",lemmatizer.lemmatize("socks"))
print("sons:",lemmatizer.lemmatize("sons"))
# Out:
# socks: sock
# sons: son

# %%
# Remove Stopwords
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data = """Data Science is one of the most trending fields to work with. It needs data to give predictions using past scenarios"""
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'once', 'about', 'between', 'their', 'been', "shouldn't", 'its', 'having', 'shouldn', 'through', 've', "you'll", 'each', "aren't", 'there', 'did', 'itself', 're', 'over', 'own', "shan't", 'below', 'just', 'doing', 'whom', 'should', 'mustn', 'very', 'they', 'in', 'under', 'again', "doesn't", 'yours', 'those', 'against', "isn't", "you'd", 'into', 'any', 'doesn', 'needn', "don't", 'weren', 'couldn', 'few', 'you', 'other', 'aren', "won't", 'had', 'while', 'we', 'during', 'won', 'further', 'but', 'isn', 'will', 'no', "needn't", 'y', 'than', 'didn', 'at', 'off', 'such', 'themselves', 'above', "haven't", 'herself', 'am', 'only', 'up', 'a', 'them', 'wasn', 'most', 'here', 'yourselves', 'which', 'have', 'haven', 's', 'down', 'when', 'd', 'be', 'was', 'shan', 'until', 'why', 'the', "mightn't", 't', 'ours', 'these', 'by', 'so', "mustn't", 'ourselves', 'same', "she's", 'after', "weren't", 'that', 'and', "hadn't", 'o', 'too', 'him', 'her', 'll', 'how', 'it', 'are', "couldn't", 'because', 'on', '
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data=nltk.word_tokenize(data)
data
# Out:
# ['Data',
#  'Science',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'trending',
#  'fields',
#  'to',
#  'work',
#  'with',
#  '.',
#  'It',
#  'needs',
#  'data',
#  'to',
#  'give',
#  'predictions',
#  'using',
#  'past',
#  'scenarios']

# %%
stops=set(stopwords.words('english'))
for word in data:
    if word in stops:
       print(word)
# Out:
# is
# of
# the
# most
# to
# with
# to

# %%
import numpy as np
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Courses Codes and Datasets/Great Learning/IMDB Dataset.csv')
print(data)
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
data.tail()
# Out:
#                                                   review sentiment
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %%
data.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
data.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
data.shape
# Out:
# (50000, 2)

# %%
data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# review       False
# sentiment    False
# dtype: bool

# %%
data['sentiment'].value_counts()
# Out:
# positive    25000
# negative    25000
# Name: sentiment, dtype: int64

# %%
# Text Normalization
# Tokenization
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
import spacy
import re
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from textblob import TextBlob
from textblob import Word
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from bs4 import BeautifulSoup
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer, WordNetLemmatizer

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install html5lib

# %%
from nltk.tokenize.toktok import ToktokTokenizer
from bs4 import BeautifulSoup
import re
# Assuming 'data' is your DataFrame and 'review' is the column containing text
tokenizers=ToktokTokenizer()
# Setting English stopwords
stopwords= nltk.corpus.stopwords.words('english')
# Removing the noisy text
def noiseremoval_text(text):
    soup=BeautifulSoup(text,'html5lib') # Use 'text' instead of 'markup'
    text=soup.get_text()
    text=re.sub('\[[^]]*\]','',text)
    return text

# %%
# Applying the function on the 'review' column
data['review'] = data['review'].apply(noiseremoval_text)
data.head()
# Out:
# <ipython-input-47-339c3ec3c1c3>:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup=BeautifulSoup(text,'html5lib') # Use 'text' instead of 'markup'
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Stemming
def stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text=''.join([ps.stem(word) for word in text.split()])
    return text

# %%
# Applying function on review column
data['review']=data['review'].apply(stemmer)
data.head()
# Out:
#                                               review sentiment
# 0  oneoftheotherreviewhamentionthatafterwatchjust...  positive
# 1  awonderlittlproduction.thefilmtechniquisveriun...  positive
# 2  ithoughtthiwaawonderwaytospendtimeonatoohotsum...  positive
# 3  basicthere'afamiliwherealittlboy(jake)thinkthe...  negative
# 4  pettermattei'"loveinthetimeofmoney"isavisualst...  positive

# %%
from nltk.tokenize.toktok import ToktokTokenizer
import nltk

# Assuming 'data' is your DataFrame and 'review' is the column containing text
# Also assuming 'stopwords' is already defined

def removing_stopwords(text, is_lower_case=False):
# Tokenization of text
    tokenizers=ToktokTokenizer()
# Setting english stopwords
    tokens=tokenizers.tokenize(text)
    tokens=[i.strip() for i in tokens]
    if is_lower_case:
        filtokens=[i for i in tokens if i not in stopwords]
    else:
        filtokens=[i for i in tokens if i.lower() not in stopwords]
    filtered_texts=' '.join(filtokens)
    return filtered_texts

# %%
# Applying the function on the 'review' column
data['review'] = data['review'].apply(removing_stopwords)
data.head()
# Out:
#                                               review sentiment
# 0  oneoftheotherreviewhamentionthatafterwatchjust...  positive
# 1  awonderlittlproduction.thefilmtechniquisveriun...  positive
# 2  ithoughtthiwaawonderwaytospendtimeonatoohotsum...  positive
# 3  basicthere ' afamiliwherealittlboy( jake ) thi...  negative
# 4  pettermattei ' " loveinthetimeofmoney " isavis...  positive

# %%
# Train Test split
# split the dataset
# train dataset
train_reviews_data=data.review[:30000]
# test dataset
test_reviews_data=data.review[30000:]

# %%
# Bag of words(BOW)
# Count Vectorizer for bag of words
cv=CountVectorizer(min_df=0,max_df=1,binary=False,ngram_range=(1,3))
# Transformed train reviews
cv_train=cv.fit_transform(train_reviews_data)
# Transformed test reviews
cv_test=cv.fit_transform(test_reviews_data)
print('BOW_cv_train:',cv_train.shape)
print('BOW_cv_test:',cv_test.shape)
# Out:
# BOW_cv_train: (30000, 2744835)
# BOW_cv_test: (20000, 1860167)

# %%
vocab=cv.get_feature_names_out()
vocab
# Out:
# array(['00 19', '00 19 theend',
#        '00 aftercohnhungupwellboughtthebookandreadit', ...,
#        'ýthýnkuzakýstheoneofthebestfilmofalltimeandeverybodimustrealizthimovie',
#        'ýthýnkuzakýstheoneofthebestfilmofalltimeandeverybodimustrealizthimovie imaturkishboyandabigcinemafun',
#        'ýthýnkuzakýstheoneofthebestfilmofalltimeandeverybodimustrealizthimovie imaturkishboyandabigcinemafun andinthidayourcinemaindustriishighup'],
#       dtype=object)

# %%
# TF-IDE
# TfidfVectorizer
tf=TfidfVectorizer(min_df=0,max_df=1,use_idf=True,ngram_range=(1,3))
# Transformed train reviews
tf_train=tf.fit_transform(train_reviews_data)
# Transformed test reviews
tf_test=tf.fit_transform(test_reviews_data)
print('Tfidf_train:',tf_train.shape)
print('Tfidf_test:',tf_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-652e1f7c6aad> in <cell line: 3>()
#       1 # TF-IDE
#       2 # TfidfVectorizer
# ----> 3 tf=TfidfVectorizer(min_df=0,max_df=1,use_idf=True,ngram_range=(1,3))
#       4 # Transformed train reviews
#       5 tf_train=tf.fit_transform(train_reviews_data)
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
# Label Encoding
# labeling the sentiment data
label=LabelBinarizer()
# transformed sentiment data
sentiment_data=label.fit_transform(data['sentiment'])
print(sentiment_data.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0b63ca05a3a1> in <cell line: 3>()
#       1 # Label Encoding
#       2 # labeling the sentiment data
# ----> 3 label=LabelBinarizer()
#       4 # transformed sentiment data
#       5 sentiment_data=label.fit_transform(data['sentiment'])
#
# NameError: name 'LabelBinarizer' is not defined

# %%
train_data=data.sentiment[:30000]
test_data=data.sentiment[30000:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b80ed3843d54> in <cell line: 1>()
# ----> 1 train_data=data.sentiment[:30000]
#       2 test_data=data.sentiment[30000:]
#
# NameError: name 'data' is not defined

# %%
# training the model[Logistic Regression]
logistic=LogisticRegression(penalty='l2',max_iter=500,C=1,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fdcf0e0454a8> in <cell line: 2>()
#       1 # training the model[Logistic Regression]
# ----> 2 logistic=LogisticRegression(penalty='l2',max_iter=500,C=1,random_state=42)
#
# NameError: name 'LogisticRegression' is not defined

# %%
# Fitting the model for Bag of words
lr_bow=logistic.fit(cv_train,train_data)
print(lr_bow)
# Out:
# LogisticRegression(C=1, max_iter=500, random_state=42)

# %%
# Fitting the model for tfidf features
lr_tfidf=logistic.fit(tf_train,train_reviews_data)
print(lr_tfidf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83167f7fd383> in <cell line: 2>()
#       1 # Fitting the model for tfidf features
# ----> 2 lr_tfidf=logistic.fit(tf_train,train_reviews_data)
#       3 print(lr_tfidf)
#
# NameError: name 'logistic' is not defined

# %%
# Predicting the model for bag of words
lr_bow_predict=logistic.predict(cv_test)
print(lr_bow_predict)
